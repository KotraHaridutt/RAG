# %% [markdown]
# ### Document Structure

# %%
from langchain_core.documents import Document

# %%
doc = Document(
    page_content="There is a Prague International Chess Competetion going on.",
    metadata={
        'location':'Prague',
        'start_date':'25-02-2026',
        'total_players':7,


    }
)

doc
# Out:
# Document(metadata={'location': 'Prague', 'start_date': '25-02-2026', 'total_players': 7}, page_content='There is a Prague International Chess Competetion going on.')

# %%
from langchain_community.document_loaders import TextLoader, DirectoryLoader, PyMuPDFLoader, PyPDFLoader

loader = TextLoader(
    "../data/text_files/chess.txt",
    encoding='utf-8'
)

content = loader.load()
content
# Out:
# [Document(metadata={'source': '../data/text_files/chess.txt'}, page_content='Chess is a board game for two players, played on a square board consisting of 64 squares arranged in an 8×8 grid. The players, referred to as "White" and "Black", each control sixteen pieces: one king, one queen, two rooks, two bishops, two knights, and eight pawns, with each piece type having a different pattern of movement. An enemy piece may be captured (removed from the board) by moving one\'s own piece onto the square it occupies. The object of the game is to "checkmate" (threaten with inescapable capture) the enemy king. There are also several ways a game can end in a draw.\n\n    The rules of chess are published by FIDE (Fédération Internationale des Échecs; "International Chess Federation"), world governing body of chess, in its Handbook.[2] Rules published by national governing bodies, or by unaffiliated chess organizations, commercial publishers, etc., may differ in some details. FIDE\'s rules were most recently revised in 2023.\n\n')]

# %%
directories_content = DirectoryLoader(
    "../data/text_files",
    glob="**/*.txt",
    loader_cls= TextLoader,
    loader_kwargs={'encoding':'utf-8'},
    show_progress=True
)

directories_content.load()
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 1521.88it/s]
# [Document(metadata={'source': '../data/text_files/chess.txt'}, page_content='Chess is a board game for two players, played on a square board consisting of 64 squares arranged in an 8×8 grid. The players, referred to as "White" and "Black", each control sixteen pieces: one king, one queen, two rooks, two bishops, two knights, and eight pawns, with each piece type having a different pattern of movement. An enemy piece may be captured (removed from the board) by moving one\'s own piece onto the square it occupies. The object of the game is to "checkmate" (threaten with inescapable capture) the enemy king. There are also several ways a game can end in a draw.\n\n    The rules of chess are published by FIDE (Fédération Internationale des Échecs; "International Chess Federation"), world governing body of chess, in its Handbook.[2] Rules published by national governing bodies, or by unaffiliated chess organizations, commercial publishers, etc., may differ in some details. FIDE\'s rules were most recently revised in 2023.\n\n')]

# %%
pdf_content = PyMuPDFLoader(
    "../data/pdf's/us_politics_page_2.pdf"
    
)
pdf_content.load()
# Out:
# [Document(metadata={'producer': 'ReportLab PDF Library - www.reportlab.com', 'creator': '(unspecified)', 'creationdate': '2026-02-28T14:16:40+00:00', 'source': "../data/pdf's/us_politics_page_2.pdf", 'file_path': "../data/pdf's/us_politics_page_2.pdf", 'total_pages': 1, 'format': 'PDF 1.4', 'title': '(anonymous)', 'author': '(anonymous)', 'subject': '(unspecified)', 'keywords': '', 'moddate': '2026-02-28T14:16:40+00:00', 'trapped': '', 'modDate': "D:20260228141640+00'00'", 'creationDate': "D:20260228141640+00'00'", 'page': 0}, page_content='Political Parties in the United States\nPolitical parties play a central role in organizing elections and shaping public policy in the United States.\nAlthough the Constitution does not explicitly mention political parties, they developed quickly in the\nearly years of the republic as leaders disagreed about the role of government, economic policy, and\nforeign relations.\nToday, the political landscape is largely dominated by two major parties: the Democratic Party and the\nRepublican Party. These parties compete in elections at local, state, and national levels, influencing\nlegislative agendas, policy debates, and voter mobilization efforts across the country.')]

# %%
directory_content_pdf = DirectoryLoader(
    "../data/pdf's",
    glob="**/*.pdf",
    show_progress=True,
    loader_cls=PyMuPDFLoader

)

directory_content_pdf.load()
# Out:
# 100%|██████████| 4/4 [00:00<00:00, 214.75it/s]
# [Document(metadata={'producer': 'ReportLab PDF Library - www.reportlab.com', 'creator': '(unspecified)', 'creationdate': '2026-02-28T14:16:40+00:00', 'source': "../data/pdf's/us_politics_page_3.pdf", 'file_path': "../data/pdf's/us_politics_page_3.pdf", 'total_pages': 1, 'format': 'PDF 1.4', 'title': '(anonymous)', 'author': '(anonymous)', 'subject': '(unspecified)', 'keywords': '', 'moddate': '2026-02-28T14:16:40+00:00', 'trapped': '', 'modDate': "D:20260228141640+00'00'", 'creationDate': "D:20260228141640+00'00'", 'page': 0}, page_content='The U.S. Electoral System\nElections in the United States are conducted through a decentralized system administered primarily by\nstate governments. This means that election procedures such as voter registration rules, ballot design,\nand polling processes can vary from one state to another. Despite these differences, federal laws\nestablish baseline protections for voting rights and election integrity.\nPresidential elections are conducted through the Electoral College, a mechanism in which voters\ntechnically select electors who then vote for the president. This system reflects a compromise between\ndirect popular voting and selection by Congress, and it remains a distinctive feature of American\npolitical institutions.'),
#  Document(metadata={'producer': 'ReportLab PDF Library - www.reportlab.com', 'creator': '(unspecified)', 'creationdate': '2026-02-28T14:16:40+00:00', 'source': "../data/pdf's/us_politics_page_1.pdf", 'file_path': "../data/pdf's/us_politics_page_1.pdf", 'total_pages': 1, 'format': 'PDF 1.4', 'title': '(anonymous)', 'author': '(anonymous)', 'subject': '(unspecified)', 'keywords': '', 'moddate': '2026-02-28T14:16:40+00:00', 'trapped': '', 'modDate': "D:20260228141640+00'00'", 'creationDate': "D:20260228141640+00'00'", 'page': 0}, page_content='The Structure of the U.S. Government\nThe United States operates under a constitutional federal republic. Power is divided between a national\ngovernment and individual state governments. The system is designed to balance authority so that no\nsingle institution dominates political decision-making. This structure emerged from debates during the\nConstitutional Convention of 1787, where the founders attempted to reconcile strong federal authority\nwith protections for state sovereignty.\nAt the federal level, the government is divided into three branches: legislative, executive, and judicial.\nEach branch has distinct responsibilities and powers, which are defined by the Constitution. This\nseparation of powers is reinforced by a system of checks and balances that allows each branch to limit\nthe authority of the others when necessary.'),
#  Document(metadata={'producer': 'ReportLab PDF Library - www.reportlab.com', 'creator': '(unspecified)', 'creationdate': '2026-02-28T14:16:40+00:00', 'source': "../data/pdf's/us_politics_page_4.pdf", 'file_path': "../data/pdf's/us_politics_page_4.pdf", 'total_pages': 1, 'format': 'PDF 1.4', 'title': '(anonymous)', 'author': '(anonymous)', 'subject': '(unspecified)', 'keywords': '', 'moddate': '2026-02-28T14:16:40+00:00', 'trapped': '', 'modDate': "D:20260228141640+00'00'", 'creationDate': "D:20260228141640+00'00'", 'page': 0}, page_content='Public Policy and Political Debate\nPublic policy in the United States is shaped through an interaction of elected officials, interest groups,\nexperts, and citizens. Issues such as healthcare, taxation, national security, climate policy, and\neducation frequently dominate political debates. Policymaking typically involves negotiation and\ncompromise across multiple institutions and levels of government.\nPolitical debate is also strongly influenced by media coverage, public opinion, and advocacy\norganizations. Modern technology and social media have accelerated the spread of political\ninformation, enabling citizens to engage with political discussions more rapidly while also raising\nconcerns about misinformation and polarization.'),
#  Document(metadata={'producer': 'ReportLab PDF Library - www.reportlab.com', 'creator': '(unspecified)', 'creationdate': '2026-02-28T14:16:40+00:00', 'source': "../data/pdf's/us_politics_page_2.pdf", 'file_path': "../data/pdf's/us_politics_page_2.pdf", 'total_pages': 1, 'format': 'PDF 1.4', 'title': '(anonymous)', 'author': '(anonymous)', 'subject': '(unspecified)', 'keywords': '', 'moddate': '2026-02-28T14:16:40+00:00', 'trapped': '', 'modDate': "D:20260228141640+00'00'", 'creationDate': "D:20260228141640+00'00'", 'page': 0}, page_content='Political Parties in the United States\nPolitical parties play a central role in organizing elections and shaping public policy in the United States.\nAlthough the Constitution does not explicitly mention political parties, they developed quickly in the\nearly years of the republic as leaders disagreed about the role of government, economic policy, and\nforeign relations.\nToday, the political landscape is largely dominated by two major parties: the Democratic Party and the\nRepublican Party. These parties compete in elections at local, state, and national levels, influencing\nlegislative agendas, policy debates, and voter mobilization efforts across the country.')]

# %%
from langchain_community.document_loaders import CSVLoader

csv_content = CSVLoader(
    "../data/csv's/weather_dataset.csv",
    source_column='City' #in metadate 'source' 
)
csv_content.load()
# Out:
# [Document(metadata={'source': 'Hyderabad', 'row': 0}, page_content='City: Hyderabad\nTemperature_C: 34\nHumidity_%: 45\nWind_kmph: 12\nRainfall_mm: 5\nAQI: 82'),
#  Document(metadata={'source': 'Delhi', 'row': 1}, page_content='City: Delhi\nTemperature_C: 36\nHumidity_%: 40\nWind_kmph: 10\nRainfall_mm: 2\nAQI: 120'),
#  Document(metadata={'source': 'Mumbai', 'row': 2}, page_content='City: Mumbai\nTemperature_C: 32\nHumidity_%: 70\nWind_kmph: 15\nRainfall_mm: 20\nAQI: 95'),
#  Document(metadata={'source': 'Chennai', 'row': 3}, page_content='City: Chennai\nTemperature_C: 35\nHumidity_%: 65\nWind_kmph: 14\nRainfall_mm: 15\nAQI: 88'),
#  Document(metadata={'source': 'Bangalore', 'row': 4}, page_content='City: Bangalore\nTemperature_C: 30\nHumidity_%: 55\nWind_kmph: 9\nRainfall_mm: 10\nAQI: 70'),
#  Document(metadata={'source': 'Kolkata', 'row': 5}, page_content='City: Kolkata\nTemperature_C: 33\nHumidity_%: 60\nWind_kmph: 11\nRainfall_mm: 18\nAQI: 110'),
#  Document(metadata={'source': 'Pune', 'row': 6}, page_content='City: Pune\nTemperature_C: 31\nHumidity_%: 50\nWind_kmph: 13\nRainfall_mm: 7\nAQI: 75'),
#  Document(metadata={'source': 'Jaipur', 'row': 7}, page_content='City: Jaipur\nTemperature_C: 37\nHumidity_%: 35\nWind_kmph: 8\nRainfall_mm: 1\nAQI: 130'),
#  Document(metadata={'source': 'Ahmedabad', 'row': 8}, page_content='City: Ahmedabad\nTemperature_C: 38\nHumidity_%: 30\nWind_kmph: 7\nRainfall_mm: 0\nAQI: 140'),
#  Document(metadata={'source': 'Lucknow', 'row': 9}, page_content='City: Lucknow\nTemperature_C: 35\nHumidity_%: 42\nWind_kmph: 10\nRainfall_mm: 3\nAQI: 105'),
#  Document(metadata={'source': 'Bhopal', 'row': 10}, page_content='City: Bhopal\nTemperature_C: 34\nHumidity_%: 47\nWind_kmph: 9\nRainfall_mm: 4\nAQI: 98'),
#  Document(metadata={'source': 'Patna', 'row': 11}, page_content='City: Patna\nTemperature_C: 36\nHumidity_%: 52\nWind_kmph: 11\nRainfall_mm: 6\nAQI: 115')]

# %%
import os
from pathlib import Path
from dotenv import load_dotenv
from langchain_community.document_loaders import FireCrawlLoader

load_dotenv(Path.cwd().parent / ".env")

FIRECRAWL_API_KEY = os.getenv("FIRECRAWL_API_KEY")


loader_crawl = FireCrawlLoader(
    api_key=FIRECRAWL_API_KEY,
    url="https://chessmood.com/blog/karen-asrian",
    mode="scrape"
 )

result=loader_crawl.load()
result[0].metadata
# Out:
# {'title': 'In Memory of GM Karen Asrian',
#  'description': 'You can: 1 - be just nice, 2 - adopt a “win at all costs” mindset, or 3 – be like GM Karen Asrian.',
#  'url': 'https://chessmood.com/blog/karen-asrian',
#  'language': 'en',
#  'keywords': '',
#  'robots': None,
#  'og_title': 'In Memory of GM Karen Asrian',
#  'og_description': 'You can: 1 - be just nice, 2 - adopt a “win at all costs” mindset, or 3 – be like GM Karen Asrian.',
#  'og_url': 'https://chessmood.com/blog/karen-asrian',
#  'og_image': 'https://cdn.chessmood.com/chessmood/images/articles/881/in-memory-of-gm-karen-asrian-metawebp_6628e695ecb85.webp?v=69a30587571ba',
#  'og_audio': None,
#  'og_determiner': None,
#  'og_locale': 'en',
#  'og_locale_alternate': None,
#  'og_site_name': None,
#  'og_video': None,
#  'favicon': 'https://chessmood.com/favicon.ico?v=7.3.1',
#  'dc_terms_created': None,
#  'dc_date_created': None,
#  'dc_date': None,
#  'dc_terms_type': None,
#  'dc_type': None,
#  'dc_terms_audience': None,
#  'dc_terms_subject': None,
#  'dc_subject': None,
#  'dc_description': None,
#  'dc_terms_keywords': None,
#  'modified_time': None,
#  'published_time': None,
#  'article_tag': None,
#  'article_section': None,
#  'source_url': 'https://chessmood.com/blog/karen-asrian',
#  'status_code': 200,
#  'scrape_id': '019ca4d1-121a-74bb-a600-658a9669c263',
#  'num_pages': None,
#  'content_type': 'text/html; charset=UTF-8',
#  'proxy_used': 'basic',
#  'timezone': None,
#  'cache_state': 'hit',
#  'cached_at': '2026-02-28T15:11:04.571Z',
#  'credits_used': 1,
#  'concurrency_limited': False,
#  'concurrency_queue_duration_ms': None,
#  'error': None,
#  'og:locale': 'en',
#  'og:image': 'https://cdn.chessmood.com/chessmood/images/articles/881/in-memory-of-gm-karen-asrian-metawebp_6628e695ecb85.webp?v=69a30587571ba',
#  'csrf-token': 'i38osCoBPQxWQagPZRtrI2rwd9QP7CeR1oOKNJV6',
#  'route-name': 'web.articles.show',
#  'fb:app_id': '623910751948031',
#  'twitter:description': 'You can: 1 - be just nice, 2 - adopt a “win at all costs” mindset, or 3 – be like GM Karen Asrian.',
#  'twitter:images0': 'https://cdn.chessmood.com/chessmood/images/articles/881/in-memory-of-gm-karen-asrian-metawebp_6628e695ecb85.webp?v=69a30587571ba',
#  'og:title': 'In Memory of GM Karen Asrian',
#  'google-site-verification': 'ZT_DUiDslDb34gTjjEr9Ri6PoPBnK42IXQ_hhwEM99s',
#  'og:type': 'website',
#  'og:url': 'https://chessmood.com/blog/karen-asrian',
#  'viewport': 'width=device-width, initial-scale=1, maximum-scale=1, viewport-fit=cover',
#  'user': '',
#  'image': 'https://cdn.chessmood.com/chessmood/images/articles/881/in-memory-of-gm-karen-asrian-metawebp_6628e695ecb85.webp?v=69a30587571ba',
#  'twitter:title': 'In Memory of GM Karen Asrian',
#  'og:description': 'You can: 1 - be just nice, 2 - adopt a “win at all costs” mindset, or 3 – be like GM Karen Asrian.'}
